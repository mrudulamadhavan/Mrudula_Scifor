# %% [markdown]
# # **Inheritance in Python**
#
# The process of inheriting the characteristics of a parent class to a child class without undergoing any changes is called as **inheritance.**
#
# Inheritance is a powerful feature that improves your program by reducing duplication and enhancing readability. We can inherit properties, functions, and characteristics from a **parent class** into a **child class or derived class** with inheritance
#
#
# In inheritance, the child class acquires all the data members, properties, and functions from the parent class. Also, a child class can also provide its specific implementation to the methods of the parent class.
#
# **One important thing to remember is child class can access the parent class, whereas the parent class cannot access the child class.**
#
#
# ### **Advantages of Inheritance**
#
# * Good representation of real world relationships.
# * Inheritance allows us to add more features to the class without having to modify the class.
# * Code reusability ie, we can use the existing class to create a new class instead of creating it from scratch.
# * Inheritance is transitive in nature.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Types Of Inheritance**
# In Python, based upon the number of child and parent classes involved, there are five types of inheritance. The type of inheritance are listed below:
#
# * Single inheritance
# * Multiple Inheritance
# * Multilevel inheritance
# * Hierarchical Inheritance
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **Single Inheritance**
#
# * When a class inherits another class, this type of inheritance is called Single Inheritance. It is the most simple form of inheritance in python.
#
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)
#
# The above image shows an example of single inheritance in which class B inherits class A. Thus class A can be called a base class or **parent class**, and class B can be called a **child class** or subclass or derived class.

# %%
# Code Implementation of Single Inheritance

# Parent class
class Vehicle:
    def vehicle_info(self):
        print('Inside Vehicle class')

# Child class
class Car(Vehicle):
    def car_info(self):
        print('Inside Car class')

# Create object of Car
car = Car()

# Access vehicle's info using car object
car.vehicle_info()
car.car_info()
# Out:
# Inside Vehicle class
# Inside Car class

# %% [markdown]
# ### **Multiple Inheritance**
#
# This type of inheritance is proper when gathering features from different classes. Multiple inheritances is a concept when a child can derive from more than one parent class.
#
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)
#
# In the above image, class C has been derived by inheriting class A and class B.

# %%
# Code Implementation of Multiple Inheritance

# Parent class 1
class Person:
    def person_info(self, name, age):
        print('\n Inside Person class')
        print(' > Name:', name, '\n > Age:', age)

# Parent class 2
class Company:
    def company_info(self, company_name, location):
        print('\n Inside Company class')
        print(' > Name:', company_name, '\n > Location:', location)

# Child class
class Employee(Person, Company):
    def Employee_info(self, salary, skill):
        print('\n Inside Employee class')
        print(' > Salary:', salary, '\n > Skill:', skill)

# Create object of Employee
emp = Employee()

# access data
emp.person_info('Jessa', 28)
emp.company_info('Google', 'Atlanta')
emp.Employee_info(12000, 'Machine Learning')
# Out:
#  Inside Person class
#  > Name: Jessa
#  > Age: 28
#
#  Inside Company class
#  > Name: Google
#  > Location: Atlanta
#
#  Inside Employee class
#  > Salary: 12000
#  > Skill: Machine Learning

# %% [markdown]
# ### **Multilevel Inheritance**
#
# Multi-level inheritance is such where it enables the child class to inherit the characteristics from the immediate class which in turn will inherit the characteristics of the parent class.
#
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)
#
# Suppose three classes A, B, C. A is the superclass, B is the child class of A, C is the child class of B. In other words, we can say a chain of classes is called multilevel inheritance.

# %%
# Code Implementation of Multilevel Inheritance

# Parent class
class Vehicle:
    def vehicle_info(self):
        print('Inside Vehicle class')

# Child class 1
class Car(Vehicle):
    def car_info(self):
        print('Inside Car class')

# Child class 1a
class SportsCar(Car):
    def sports_car_info(self):
        print('Inside SportsCar class')

# Create object of SportsCar
s_car = SportsCar()

# access Vehicle's and Car info using SportsCar object
s_car.vehicle_info()
s_car.car_info()
s_car.sports_car_info()
# Out:
# Inside Vehicle class
# Inside Car class
# Inside SportsCar class

# %% [markdown]
# In the above example, we can see there are three classes named Vehicle, Car, SportsCar. Vehicle is the superclass, Car is a child of Vehicle, SportsCar is a child of Car. So we can see the chaining of classes.

# %% [markdown]
# ### **Hierarchical Inheritance**
#
# The Hierarchical inheritance enables multiple derived/child classes to inherit the characteristics of one existing parent class. In other words, we can say one parent class and multiple child classes.
#
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)
#
# In the above image, classes B, C and D inherit the same base class A.

# %%
# Code implementation of Hierarchical Inheritance
# Parent Class
class Vehicle:
    def info(self):
        print("\n This is Vehicle")

# Child class 1
class Car(Vehicle):
    def car_info(self, name):
        print(" > Car name :", name)

# Child class 2
class Truck(Vehicle):
    def truck_info(self, name):
        print(" > Truck name :", name)

obj1 = Car()
obj1.info()
obj1.car_info('BMW')

obj2 = Truck()
obj2.info()
obj2.truck_info('Ashok Leyland')
# Out:
#  This is Vehicle
#  > Car name : BMW
#
#  This is Vehicle
#  > Truck name : Ashok Leyland

# %% [markdown]
# --------------------------------------------------------------------------------
# -----------------------------------------------------------------------------
